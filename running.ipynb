# %%
# !python train.py \
--model-name 'resnet18' \
--num-epoch 50 \
--batch-size 256 \
--learning-rate 1e-3 \
--model-save-path '/scratch/hp2173/DL_MiniProject/model_checkpoint/'
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# number of parameters: 11173962
# Epoch:0 -> train_loss:1.60026, train_acc:0.41116 || valid_loss:1.35944, valid_acc:0.49408
# the current min train_loss: 1.35944
# ---------------------------------------------
# Epoch:1 -> train_loss:1.11837, train_acc:0.59557 || valid_loss:1.21714, valid_acc:0.57096
# the current min train_loss: 1.21714
# ---------------------------------------------
# Epoch:2 -> train_loss:0.88882, train_acc:0.68288 || valid_loss:0.98198, valid_acc:0.65193
# the current min train_loss: 0.98198
# ---------------------------------------------
# Epoch:3 -> train_loss:0.74099, train_acc:0.73967 || valid_loss:0.83094, valid_acc:0.70763
# the current min train_loss: 0.83094
# ---------------------------------------------
# Epoch:4 -> train_loss:0.62262, train_acc:0.78164 || valid_loss:0.91558, valid_acc:0.68543
# ...

# %%
# !python evaluate.py \
--model-name 'resnet18' \
--model-save-path '/scratch/hp2173/DL_MiniProject/model_checkpoint/'
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# number of parameters: 11173962
# test_loss: 0.3526928126811981 test_accuracy 0.9071576297283173

# %%
# !python train.py \
--model-name 'resnet_de_channel' \
--num-epoch 50 \
--batch-size 256 \
--learning-rate 1e-3 \
--model-save-path '/scratch/hp2173/DL_MiniProject/model_checkpoint/'
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# number of parameters: 2797610
# Epoch:0 -> train_loss:1.41638, train_acc:0.47815 || valid_loss:1.14010, valid_acc:0.58608
# the current min train_loss: 1.14010
# ---------------------------------------------
# Epoch:1 -> train_loss:0.96497, train_acc:0.65379 || valid_loss:1.31394, valid_acc:0.57088
# ---------------------------------------------
# Epoch:2 -> train_loss:0.78536, train_acc:0.72277 || valid_loss:0.91606, valid_acc:0.68521
# the current min train_loss: 0.91606
# ---------------------------------------------
# Epoch:3 -> train_loss:0.66861, train_acc:0.76451 || valid_loss:0.72330, valid_acc:0.74306
# the current min train_loss: 0.72330
# ---------------------------------------------
# Epoch:4 -> train_loss:0.58089, train_acc:0.79917 || valid_loss:0.78132, valid_acc:0.73080
# ---------------------------------------------
# ...

# %%
# !python evaluate.py \
--model-name 'resnet_de_channel' \
--model-save-path '/scratch/hp2173/DL_MiniProject/model_checkpoint/'
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# number of parameters: 2797610
# test_loss: 0.38564012497663497 test_accuracy 0.9005687028169632

# %%
# !python train.py \
--model-name 'resnet_stage_ratio_1131' \
--num-epoch 50 \
--batch-size 256 \
--learning-rate 1e-3 \
--model-save-path '/scratch/hp2173/DL_MiniProject/model_checkpoint/'
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# number of parameters: 1819818
# Epoch:0 -> train_loss:1.41879, train_acc:0.47571 || valid_loss:1.20993, valid_acc:0.55743
# the current min train_loss: 1.20993
# ---------------------------------------------
# Epoch:1 -> train_loss:0.98693, train_acc:0.64640 || valid_loss:1.01794, valid_acc:0.63321
# the current min train_loss: 1.01794
# ---------------------------------------------
# Epoch:2 -> train_loss:0.81039, train_acc:0.71418 || valid_loss:0.84728, valid_acc:0.70507
# the current min train_loss: 0.84728
# ---------------------------------------------
# Epoch:3 -> train_loss:0.68824, train_acc:0.75648 || valid_loss:0.77086, valid_acc:0.72969
# the current min train_loss: 0.77086
# ---------------------------------------------
# Epoch:4 -> train_loss:0.60109, train_acc:0.79064 || valid_loss:0.74783, valid_acc:0.74041
# the current min train_loss: 0.74783
# ...

# %%
# !python evaluate.py \
--model-name 'resnet_stage_ratio_1131' \
--model-save-path '/scratch/hp2173/DL_MiniProject/model_checkpoint/'
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# number of parameters: 1819818
# test_loss: 0.39248228818178177 test_accuracy 0.886328125

# %%
# !python train.py \
--model-name 'resnet_stage_ratio_2242' \
--num-epoch 50 \
--batch-size 256 \
--learning-rate 1e-3 \
--model-save-path '/scratch/hp2173/DL_MiniProject/model_checkpoint/'
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# number of parameters: 3388458
# Epoch:0 -> train_loss:1.46522, train_acc:0.46073 || valid_loss:1.56893, valid_acc:0.45556
# the current min train_loss: 1.56893
# ---------------------------------------------
# Epoch:1 -> train_loss:0.99463, train_acc:0.64303 || valid_loss:1.22337, valid_acc:0.59897
# the current min train_loss: 1.22337
# ---------------------------------------------
# Epoch:2 -> train_loss:0.78000, train_acc:0.72509 || valid_loss:1.05508, valid_acc:0.64624
# the current min train_loss: 1.05508
# ---------------------------------------------
# Epoch:3 -> train_loss:0.66512, train_acc:0.76817 || valid_loss:0.82726, valid_acc:0.71358
# the current min train_loss: 0.82726
# ---------------------------------------------
# Epoch:4 -> train_loss:0.58994, train_acc:0.79569 || valid_loss:0.68411, valid_acc:0.75979
# the current min train_loss: 0.68411
# ...

# %%
# !python evaluate.py \
--model-name 'resnet_stage_ratio_2242' \
--model-save-path '/scratch/hp2173/DL_MiniProject/model_checkpoint/'
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# number of parameters: 3388458
# test_loss: 0.38788151890039446 test_accuracy 0.8889993101358413

# %%
# !python train.py \
--model-name 'resnet_stage_ratio_2262' \
--num-epoch 50 \
--batch-size 256 \
--learning-rate 1e-3 \
--model-save-path '/scratch/hp2173/DL_MiniProject/model_checkpoint/'
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# number of parameters: 3979306
# Epoch:0 -> train_loss:1.48034, train_acc:0.45376 || valid_loss:1.45025, valid_acc:0.49233
# the current min train_loss: 1.45025
# ---------------------------------------------
# Epoch:1 -> train_loss:1.03840, train_acc:0.63070 || valid_loss:1.37761, valid_acc:0.55070
# the current min train_loss: 1.37761
# ---------------------------------------------
# Epoch:2 -> train_loss:0.81909, train_acc:0.71277 || valid_loss:1.23307, valid_acc:0.59537
# the current min train_loss: 1.23307
# ---------------------------------------------
# Epoch:3 -> train_loss:0.69343, train_acc:0.75651 || valid_loss:0.79048, valid_acc:0.72006
# the current min train_loss: 0.79048
# ---------------------------------------------
# Epoch:4 -> train_loss:0.59341, train_acc:0.79469 || valid_loss:0.90750, valid_acc:0.69228
# ...

# %%
# !python evaluate.py \
--model-name 'resnet_stage_ratio_2262' \
--model-save-path '/scratch/hp2173/DL_MiniProject/model_checkpoint/'
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# number of parameters: 3979306
# test_loss: 0.3719953253865242 test_accuracy 0.8958065271377563

# %%
# !python train.py \
--model-name 'resnet_stage_ratio_3333' \
--num-epoch 50 \
--batch-size 256 \
--learning-rate 1e-3 \
--model-save-path '/scratch/hp2173/DL_MiniProject/model_checkpoint/'
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# number of parameters: 4366250
# Epoch:0 -> train_loss:1.49247, train_acc:0.45111 || valid_loss:1.24218, valid_acc:0.56098
# the current min train_loss: 1.24218
# ---------------------------------------------
# Epoch:1 -> train_loss:1.02395, train_acc:0.62948 || valid_loss:0.99401, valid_acc:0.63349
# the current min train_loss: 0.99401
# ---------------------------------------------
# Epoch:2 -> train_loss:0.81601, train_acc:0.71005 || valid_loss:0.95092, valid_acc:0.66977
# the current min train_loss: 0.95092
# ---------------------------------------------
# Epoch:3 -> train_loss:0.68052, train_acc:0.76178 || valid_loss:0.72397, valid_acc:0.74953
# the current min train_loss: 0.72397
# ---------------------------------------------
# Epoch:4 -> train_loss:0.59107, train_acc:0.79497 || valid_loss:0.72178, valid_acc:0.74839
# the current min train_loss: 0.72178
# ...

# %%
# !python evaluate.py \
--model-name 'resnet_stage_ratio_3333' \
--model-save-path '/scratch/hp2173/DL_MiniProject/model_checkpoint/'
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# number of parameters: 4366250
# test_loss: 0.3664513811469078 test_accuracy 0.8826114445924759

# %%
# !python train.py \
--model-name 'resnet_de_channal_patchify' \
--num-epoch 50 \
--batch-size 256 \
--learning-rate 1e-3 \
--model-save-path '/scratch/hp2173/DL_MiniProject/model_checkpoint/'
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# number of parameters: 2797130
# Epoch:0 -> train_loss:1.46993, train_acc:0.46425 || valid_loss:1.35501, valid_acc:0.50587
# the current min train_loss: 1.35501
# ---------------------------------------------
# Epoch:1 -> train_loss:1.12259, train_acc:0.60161 || valid_loss:1.10567, valid_acc:0.60758
# the current min train_loss: 1.10567
# ---------------------------------------------
# Epoch:2 -> train_loss:0.95403, train_acc:0.66119 || valid_loss:1.00205, valid_acc:0.63883
# the current min train_loss: 1.00205
# ---------------------------------------------
# Epoch:3 -> train_loss:0.83541, train_acc:0.70404 || valid_loss:0.90676, valid_acc:0.67383
# the current min train_loss: 0.90676
# ---------------------------------------------
# Epoch:4 -> train_loss:0.74879, train_acc:0.73826 || valid_loss:0.81554, valid_acc:0.71487
# the current min train_loss: 0.81554
# ...

# %%
# !python evaluate.py \
--model-name 'resnet_de_channal_patchify' \
--model-save-path '/scratch/hp2173/DL_MiniProject/model_checkpoint/'
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# number of parameters: 2797130
# test_loss: 0.5307779714465142 test_accuracy 0.8375746786594391

# %%
# !python train.py \
--model-name 'resnet_de_channal_conv2by2_down' \
--num-epoch 50 \
--batch-size 256 \
--learning-rate 1e-3 \
--model-save-path '/scratch/hp2173/DL_MiniProject/model_checkpoint/'
# Out:
# ResNet(
#   (conv1): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# ...

# %%
# !python evaluate.py \
--model-name 'resnet_de_channal_conv2by2_down' \
--model-save-path '/scratch/hp2173/DL_MiniProject/model_checkpoint/'
# Out:
# ResNet(
#   (conv1): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# ...

# %%
# !python train.py \
--model-name 'resnet_de_channal_depth_conv' \
--num-epoch 50 \
--batch-size 256 \
--learning-rate 1e-3 \
--model-save-path '/scratch/hp2173/DL_MiniProject/model_checkpoint/'
# Out:
# ResNet(
#   (conv1): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# ...

# %%
# !python evaluate.py \
--model-name 'resnet_de_channal_depth_conv' \
--model-save-path '/scratch/hp2173/DL_MiniProject/model_checkpoint/'
# Out:
# ResNet(
#   (conv1): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# ...

# %%
# !python train.py \
--model-name 'resnet_de_channal_depth_conv' \
--num-epoch 50 \
--batch-size 256 \
--learning-rate 1e-3 \
--model-save-path '/scratch/hp2173/DL_MiniProject/model_checkpoint/'
# Out:
# ResNet(
#   (conv1): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# ...

# %%
# !python evaluate.py \
--model-name 'resnet_de_channal_depth_conv' \
--model-save-path '/scratch/hp2173/DL_MiniProject/model_checkpoint/'
# Out:
# ResNet(
#   (conv1): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# ...

# %%
# !python train.py \
--model-name 'resnet_de_resblock' \
--num-epoch 50 \
--batch-size 256 \
--learning-rate 1e-3 \
--model-save-path '/scratch/hp2173/DL_MiniProject/model_checkpoint/'
# Out:
# ResNet(
#   (conv1): Conv2d(3, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn1): BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(80, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(80, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(80, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(80, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# ...

# %%
# !python evaluate.py \
--model-name 'resnet_de_resblock' \
--model-save-path '/scratch/hp2173/DL_MiniProject/model_checkpoint/'
# Out:
# ResNet(
#   (conv1): Conv2d(3, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn1): BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(80, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(80, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(80, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(80, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# ...

# %%
# !python train.py \
--model-name 'resnet_de_resblock321' \
--num-epoch 50 \
--batch-size 256 \
--learning-rate 1e-3 \
--model-save-path '/scratch/hp2173/DL_MiniProject/model_checkpoint/'
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# number of parameters: 2608410
# Epoch:0 -> train_loss:1.51562, train_acc:0.43851 || valid_loss:1.58464, valid_acc:0.46213
# the current min train_loss: 1.58464
# ---------------------------------------------
# Epoch:1 -> train_loss:1.05494, train_acc:0.62223 || valid_loss:1.14761, valid_acc:0.58551
# the current min train_loss: 1.14761
# ---------------------------------------------
# Epoch:2 -> train_loss:0.86112, train_acc:0.69604 || valid_loss:0.96490, valid_acc:0.66197
# the current min train_loss: 0.96490
# ---------------------------------------------
# Epoch:3 -> train_loss:0.73232, train_acc:0.74106 || valid_loss:0.77616, valid_acc:0.73165
# the current min train_loss: 0.77616
# ---------------------------------------------
# Epoch:4 -> train_loss:0.62710, train_acc:0.78271 || valid_loss:0.94839, valid_acc:0.68200
# ...

# %%
# !python evaluate.py \
--model-name 'resnet_de_resblock321' \
--model-save-path '/scratch/hp2173/DL_MiniProject/model_checkpoint/'
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# number of parameters: 2608410
# test_loss: 0.41005943566560743 test_accuracy 0.8983341008424759

# %%
# !python train.py \
--model-name 'resnet_de_resblock141' \
--num-epoch 50 \
--batch-size 256 \
--learning-rate 1e-3 \
--model-save-path '/scratch/hp2173/DL_MiniProject/model_checkpoint/'
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# number of parameters: 3300250
# Epoch:0 -> train_loss:1.50743, train_acc:0.43996 || valid_loss:1.29428, valid_acc:0.53998
# the current min train_loss: 1.29428
# ---------------------------------------------
# Epoch:1 -> train_loss:1.04162, train_acc:0.62851 || valid_loss:1.17131, valid_acc:0.59303
# the current min train_loss: 1.17131
# ---------------------------------------------
# Epoch:2 -> train_loss:0.84452, train_acc:0.70060 || valid_loss:0.94366, valid_acc:0.67217
# the current min train_loss: 0.94366
# ---------------------------------------------
# Epoch:3 -> train_loss:0.70804, train_acc:0.75138 || valid_loss:0.81874, valid_acc:0.71827
# the current min train_loss: 0.81874
# ---------------------------------------------
# Epoch:4 -> train_loss:0.61763, train_acc:0.78594 || valid_loss:0.69575, valid_acc:0.75911
# the current min train_loss: 0.69575
# ...

# %%
# !python evaluate.py \
--model-name 'resnet_de_resblock141' \
--model-save-path '/scratch/hp2173/DL_MiniProject/model_checkpoint/'
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# number of parameters: 3300250
# test_loss: 0.3831006079912186 test_accuracy 0.9012867659330368

# %% [markdown]
# # Training Config

# %%
# !python train.py \
--model-name 'resnet_de_resblock' \
--num-epoch 50 \
--batch-size 64 \
--learning-rate 1e-3 \
--model-save-path './model_checkpoint'

# %%
# !python train.py \
--model-name 'resnet_de_resblock' \
--num-epoch 50 \
--batch-size 128 \
--learning-rate 1e-3 \
--model-save-path './model_checkpoint'

# %%
# !python train.py \
--model-name 'resnet_de_resblock' \
--num-epoch 50 \
--batch-size 256 \
--learning-rate 1e-3 \
--model-save-path './model_checkpoint'

# %%
# !python train.py \
--model-name 'resnet_de_resblock' \
--num-epoch 50 \
--batch-size 512 \
--learning-rate 1e-3 \
--model-save-path './model_checkpoint'

# %%
# !python train.py \
--model-name 'resnet_de_resblock' \
--num-epoch 50 \
--batch-size 1024 \
--learning-rate 1e-3 \
--model-save-path './model_checkpoint'
